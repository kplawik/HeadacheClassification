# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/migraine.csv')
pd.set_option('display.float_format', '{:0.2f}'.format)

# %%
df.describe()
# Out:
#          Age  Duration  Frequency  Location  Character  Intensity  Nausea  \
# count 400.00    400.00     400.00    400.00     400.00     400.00  400.00
# mean   31.70      1.61       2.37      0.97       0.98       2.47    0.99
# std    12.14      0.77       1.68      0.27       0.28       0.77    0.11
# min    15.00      1.00       1.00      0.00       0.00       0.00    0.00
# 25%    22.00      1.00       1.00      1.00       1.00       2.00    1.00
# 50%    28.00      1.00       2.00      1.00       1.00       3.00    1.00
# 75%    40.00      2.00       4.00      1.00       1.00       3.00    1.00
# max    77.00      3.00       8.00      2.00       2.00       3.00    1.00
#
#        Vomit  Phonophobia  Photophobia  ...  Dysarthria  Vertigo  Tinnitus  \
# count 400.00       400.00       400.00  ...      400.00   400.00    400.00
# mean    0.32         0.98         0.98  ...        0.00     0.12      0.06
# std     0.47         0.15         0.14  ...        0.05     0.33      0.24
# ...

# %%
df.isna().sum()
# Out:
# Age              0
# Duration         0
# Frequency        0
# Location         0
# Character        0
# Intensity        0
# Nausea           0
# Vomit            0
# Phonophobia      0
# Photophobia      0
# Visual           0
# Sensory          0
# Dysphasia        0
# Dysarthria       0
# Vertigo          0
# Tinnitus         0
# Hypoacusis       0
# Diplopia         0
# Visual_defect    0
# Ataxia           0
# Conscience       0
# Paresthesia      0
# DPF              0
# Type             0
# dtype: int64
